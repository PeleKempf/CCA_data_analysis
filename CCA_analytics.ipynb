# %%
import pandas as pd

# %%
game_data = pd.read_csv('game_data.csv')

# %%
game_data
# Out:
#      wpm  accuracy  mistakes
# 0   42.9       0.0         4
# 1    wpm  accuracy  mistakes
# 2   76.8       0.0         4
# 3    wpm  accuracy  mistakes
# 4   54.7       5.1         0
# 5    wpm  accuracy  mistakes
# 6   48.0       3.4        21
# 7    wpm  accuracy  mistakes
# 8   48.0       3.4        21
# 9    wpm  accuracy  mistakes
# 10  48.0       3.4        21
# 11   wpm  accuracy  mistakes
# 12  36.0      49.0       131
# 13   wpm  accuracy  mistakes
# 14  36.0      49.0       131
# 15   wpm  accuracy  mistakes
# 16  36.0      49.0       131
# 17   wpm  accuracy  mistakes
# 18  28.8      17.5       212
# 19   wpm  accuracy  mistakes
# 20  32.5     100.0         0
# 21   wpm  accuracy  mistakes
# 22  35.4      26.2       440
# 23   wpm  accuracy  mistakes
# 24  35.4      26.2       440
# 25   wpm  accuracy  mistakes
# 26  33.6      50.9       161
