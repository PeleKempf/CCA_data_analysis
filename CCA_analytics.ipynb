# %%
import pandas as pd

# %%
game_data = pd.read_csv('game_data.csv')

# %%
game_data
# Out:
#      wpm  accuracy  mistakes
# 0   57.5       3.9        47
# 1   38.5      99.6         1
# 2   32.4      13.7       278
# 3   32.1      31.8       281
# 4   39.1      55.6        63
# 5   36.2      93.6        19
# 6   30.9       9.6       248
# 7   40.0      65.9       112
# 8   35.2      20.1       477
# 9   40.4      99.6         1
# 10  35.5      52.9       193
# 11  42.3      47.9       130
# 12  35.6      74.5       105
# 13  42.7      13.6       216
# 14  36.4       5.8       306
# 15  35.7      91.8        21
# 16  39.6      73.5       107
# 17  39.1      98.5         4
# 18  41.0      96.9         7
# 19  39.3      99.1         2
# 20  37.3      10.1       529
# 21  37.7      31.8       279
# 22  36.6      99.6         1
# 23  40.6      58.0       173
# 24  38.4      99.2         2
# 25  45.7      50.6       127
# 26  38.6      76.7        91
# 27  41.0      98.8         3
# 28  40.3      25.2       308
# 29  37.1      92.9        19
# 30  43.2      99.2         2
# 31  40.6      75.1        64
# 32  40.7      90.9        29
# 33  47.7      32.0       280
# 34  39.5       8.9       540
# 35  43.0      42.0       239
# 36  44.8       8.2       236
# 37  38.4      87.9        34
# 38  44.0      25.5       306
# 39  32.4      42.7       187

# %%
game_data['wpm'].mean().round(1)
# Out:
# 39.4

# %%
game_data.plot(kind = 'scatter', x = 'wpm', y = 'accuracy')
# Out:
# <Axes: xlabel='wpm', ylabel='accuracy'>

# %% [markdown]
# <h3> The correlation is a weak negative correlation showing wpm doesn't have a great effect on accuracy <h3>
